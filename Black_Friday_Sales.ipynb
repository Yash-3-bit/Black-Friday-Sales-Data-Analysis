# %% [markdown]
# ## Dataset walkthrough

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('BlackFriday.csv')

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.shape
# Out:
# (537577, 12)

# %%
df.isna().any()
# Out:
# User_ID                       False
# Product_ID                    False
# Gender                        False
# Age                           False
# Occupation                    False
# City_Category                 False
# Stay_In_Current_City_Years    False
# Marital_Status                False
# Product_Category_1            False
# Product_Category_2             True
# Product_Category_3             True
# Purchase                      False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
del df['Product_Category_2']
del df['Product_Category_3']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Purchase                    537577 non-null  int64
# dtypes: int64(5), object(5)
# memory usage: 41.0+ MB

# %%
df.shape
# Out:
# (537577, 10)

# %% [markdown]
# ## Analyzing Columns

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Purchase'],
#       dtype='object')

# %%
for i in df.columns:
    print(i)
# Out:
# User_ID
# Product_ID
# Gender
# Age
# Occupation
# City_Category
# Stay_In_Current_City_Years
# Marital_Status
# Product_Category_1
# Purchase

# %%
df['User_ID'] # there are repeated user_id's in the column.
# Out:
# 0         1000001
# 1         1000001
# 2         1000001
# 3         1000001
# 4         1000002
#            ...
# 537572    1004737
# 537573    1004737
# 537574    1004737
# 537575    1004737
# 537576    1004737
# Name: User_ID, Length: 537577, dtype: int64

# %%
df['User_ID'].nunique() # there are 5891 original customers are there, and these guys purchased like 53lac products.
# Out:
# 5891

# %%
df['Product_ID'].nunique()
# Out:
# 3623

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Marital_Status'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %%
df['Purchase'].agg([np.mean,np.sum,'max',min])
# Out:
# mean    9.333860e+03
# sum     5.017668e+09
# max     2.396100e+04
# min     1.850000e+02
# Name: Purchase, dtype: float64

# %%
df['Purchase'].sum()
# Out:
# 5017668378

# %%
df['Purchase'].mean()
# Out:
# 9333.859852635065

# %%
for i in df.columns:
    print(i,df[i].nunique())
# Out:
# User_ID 5891
# Product_ID 3623
# Gender 2
# Age 7
# Occupation 21
# City_Category 3
# Stay_In_Current_City_Years 5
# Marital_Status 2
# Product_Category_1 18
# Purchase 17959

# %% [markdown]
# ## Analyzing Gender

# %%
df['Gender']
# Out:
# 0         F
# 1         F
# 2         F
# 3         F
# 4         M
#          ..
# 537572    M
# 537573    M
# 537574    M
# 537575    M
# 537576    M
# Name: Gender, Length: 537577, dtype: object

# %%
df['Gender'].value_counts()
# Out:
# M    405380
# F    132197
# Name: Gender, dtype: int64

# %%
df['Gender'].value_counts().plot(kind='pie',autopct='%1.2f',legend=True,title='gender ratio')
# Out:
# <Axes: title={'center': 'gender ratio'}, ylabel='Gender'>

# %%
df.groupby('Gender')['Purchase'].sum()
# Out:
# Gender
# F    1164624021
# M    3853044357
# Name: Purchase, dtype: int64

# %%
df.groupby('Gender')['Purchase'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
df.groupby('Gender')['Purchase'].sum().plot(kind='pie',autopct='%1.2f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Gender')['Purchase'].mean()
# Out:
# Gender
# F    8809.761349
# M    9504.771713
# Name: Purchase, dtype: float64

# %%
df.groupby('Gender')['Purchase'].mean().plot(kind='pie',autopct='%1.2f')
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# ## Analyzing Age & Martial Status

# %%
df.sample(2)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 136805  1003147  P00200842      M  26-35          14             C
# 126     1000024  P00248942      F  26-35           7             A
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 136805                          0               0                   8
# 126                             3               1                   1
#
#         Purchase
# 136805      4165
# 126        15774

# %%
df['Age'].value_counts()
# Out:
# 26-35    214690
# 36-45    107499
# 18-25     97634
# 46-50     44526
# 51-55     37618
# 55+       20903
# 0-17      14707
# Name: Age, dtype: int64

# %%
df.groupby('Age').size()
# Out:
# Age
# 0-17      14707
# 18-25     97634
# 26-35    214690
# 36-45    107499
# 46-50     44526
# 51-55     37618
# 55+       20903
# dtype: int64

# %%
df.groupby('Age').size().plot(kind='bar',figsize=(10,5),title='Purchase distribution by age')
# Out:
# <Axes: title={'center': 'Purchase distribution by age'}, xlabel='Age'>

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df[df['Age']=='0-17']
# Out:
#         User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0       1000001  P00069042      F  0-17          10             A
# 1       1000001  P00248942      F  0-17          10             A
# 2       1000001  P00087842      F  0-17          10             A
# 3       1000001  P00085442      F  0-17          10             A
# 85      1000019  P00112542      M  0-17          10             A
# ...         ...        ...    ...   ...         ...           ...
# 537280  1004690  P00242742      F  0-17          10             C
# 537281  1004690  P00226442      F  0-17          10             C
# 537282  1004690  P00181442      F  0-17          10             C
# 537283  1004690  P00192042      F  0-17          10             C
# 537354  1004707  P00253042      M  0-17           0             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
len(df[df['Age']=='0-17'])
# Out:
# 14707

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
for i in df['Age'].unique():
    print(i,len(df[df['Age']==i]))
# Out:
# 0-17 14707
# 55+ 20903
# 26-35 214690
# 46-50 44526
# 51-55 37618
# 36-45 107499
# 18-25 97634

# %%
df['Product_ID'].nunique()
# Out:
# 3623

# %%
df[df['Age']==i]['Product_ID'].nunique()
# Out:
# 3213

# %%
lst=[]
for i in df['Age'].unique():
    lst.append([i,df[df['Age']==i] ['Product_ID'].nunique()])
data = pd.DataFrame(lst,columns=['Age','Products'])
data
# Out:
#      Age  Products
# 0   0-17      2300
# 1    55+      2573
# 2  26-35      3419
# 3  46-50      3099
# 4  51-55      2877
# 5  36-45      3318
# 6  18-25      3213

# %%
data.plot(kind='bar',x='Age',y='Products')
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby('Age')['Purchase'].sum().plot(kind='pie',autopct='%1.2f',legend=True,figsize=(14,7))
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Marital_Status').size()
# Out:
# Marital_Status
# 0    317817
# 1    219760
# dtype: int64

# %%
df['Marital_Status'].value_counts()
# Out:
# 0    317817
# 1    219760
# Name: Marital_Status, dtype: int64

# %%
df['Marital_Status'].value_counts().plot(kind='pie',autopct='%1.2f')
# Out:
# <Axes: ylabel='Marital_Status'>

# %%
df['Gender'].value_counts()
# Out:
# M    405380
# F    132197
# Name: Gender, dtype: int64

# %%
df['Gender'].value_counts().plot(kind='pie',autopct='%1.2f')
# Out:
# <Axes: ylabel='Gender'>

# %% [markdown]
# ## Multi Column Analysis

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
sns.countplot(x='Age',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x='Gender',hue='Age',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x='Gender',hue='Marital_Status',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x='Marital_Status',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x=df['City_Category'])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('City_Category').size().plot(kind='pie',autopct='%1.2f')
# Out:
# <Axes: >

# %%
sns.countplot(x='City_Category',hue='Age',data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x='Marital_Status',hue='Age',data=df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x='City_Category',hue='Gender',data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('City_Category')['Purchase'].sum().plot(kind='pie',autopct='%1.2f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('City_Category')['Purchase'].mean().plot(kind='pie',autopct='%1.2f',title='purchase_power of the cities')
# Out:
# <Axes: title={'center': 'purchase_power of the cities'}, ylabel='Purchase'>

# %% [markdown]
# ## Occupation and Product Analysis

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
sns.countplot(x=df['Stay_In_Current_City_Years'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue='Marital_Status',data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby('Stay_In_Current_City_Years').size()
# Out:
# Stay_In_Current_City_Years
# 0      72725
# 1     189192
# 2      99459
# 3      93312
# 4+     82889
# dtype: int64

# %%
df.groupby('Stay_In_Current_City_Years').size().plot(kind='pie',autopct='%1.2f')
# Out:
# <Axes: >

# %%
df.groupby('Stay_In_Current_City_Years')['Purchase'].sum()
# Out:
# Stay_In_Current_City_Years
# 0      672505429
# 1     1763243917
# 2      934676626
# 3      872531130
# 4+     774711276
# Name: Purchase, dtype: int64

# %%
df.groupby('Stay_In_Current_City_Years')['Purchase'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
sns.countplot(x=df['Occupation'])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').size().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation').size().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation')['Purchase'].sum().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation')['Purchase'].mean().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
sns.countplot(x='Occupation',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x='Occupation',hue='Marital_Status',data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation')['Product_ID'].nunique()
# Out:
# Occupation
# 0     3243
# 1     3020
# 2     2892
# 3     2657
# 4     3174
# 5     2344
# 6     2724
# 7     3070
# 8     1026
# 9     1820
# 10    2110
# 11    2235
# 12    2664
# 13    1946
# 14    2680
# 15    2168
# 16    2863
# 17    2831
# 18    2047
# 19    2303
# 20    3147
# Name: Product_ID, dtype: int64

# %%
df.groupby('Occupation')['Product_ID'].nunique().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Product_Category_1').size()
# Out:
# Product_Category_1
# 1     138353
# 2      23499
# 3      19849
# 4      11567
# 5     148592
# 6      20164
# 7       3668
# 8     112132
# 9        404
# 10      5032
# 11     23960
# 12      3875
# 13      5440
# 14      1500
# 15      6203
# 16      9697
# 17       567
# 18      3075
# dtype: int64

# %%
df.groupby('Product_Category_1').size().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1')['Purchase'].size().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %% [markdown]
# ## combining Gender & Martial Status

# %%
df.sample(5)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 396213  1001016  P00010342      M    55+          16             C
# 67421   1004327  P00221642      M  36-45          17             B
# 484352  1002634  P00317842      M    55+           1             A
# 412216  1003481  P00059442      M  18-25           4             B
# 496711  1004458  P00031442      F  26-35           4             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 396213                          3               0                   8
# 67421                           1               0                   5
# 484352                          3               1                   8
# 412216                          1               1                   6
# 496711                          1               0                   5
#
#         Purchase
# 396213      5910
# 67421       6960
# 484352      5831
# 412216     15972
# 496711      5178

# %%
df.iloc[:,[2,7]]
# Out:
#        Gender  Marital_Status
# 0           F               0
# 1           F               0
# 2           F               0
# 3           F               0
# 4           M               0
# ...       ...             ...
# 537572      M               0
# 537573      M               0
# 537574      M               0
# 537575      M               0
# 537576      M               0
#
# [537577 rows x 2 columns]

# %%
df.loc[(df['Gender']=='F') & (df['Marital_Status']==0)]
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 14      1000006  P00231342      F  51-55           9             A
# ...         ...        ...    ...    ...         ...           ...
# 537316  1004699  P00042942      F  18-25           0             C
# 537317  1004699  P00184442      F  18-25           0             C
# 537404  1004719  P00070042      F  36-45           9             C
# 537475  1004727  P00295942      F    55+           0             C
# 537476  1004727  P00351142      F    55+           0             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.groupby('Gender')['Marital_Status'].sum()
# Out:
# Gender
# F     55223
# M    164537
# Name: Marital_Status, dtype: int64

# %%
df.pivot_table('Marital_Status','Gender')
# Out:
#         Marital_Status
# Gender
# F             0.417733
# M             0.405883

# %%
l = []
for i in range(len(df)):
    l.append(df['Gender'][i]+'_'+str(df['Marital_Status'][i]))
df['Marital_Gender']=l

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase  \
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969
#
#   Marital_Gender
# 0            F_0
# 1            F_0
# 2            F_0
# 3            F_0
# 4            M_0

# %%
sns.countplot(x=df['Marital_Gender'])
# Out:
# <Axes: xlabel='Marital_Gender', ylabel='count'>

# %%
sns.countplot(x=df['Product_Category_1'],hue=df['Marital_Gender'])
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x=df['Age'],hue=df['Marital_Gender'])
# Out:
# <Axes: xlabel='Age', ylabel='count'>
